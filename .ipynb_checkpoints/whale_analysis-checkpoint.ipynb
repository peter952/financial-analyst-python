# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_path = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(whale_returns_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns = whale_returns.dropna()

# %%
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
whale_returns.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
#whale_returns = whale_returns.set_index("Date")

# %%
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
whale_returns.sort_index(ascending = True, inplace = True)

# %%
whale_returns.index
# Out:
# DatetimeIndex(['2015-03-03', '2015-03-04', '2015-03-05', '2015-03-06',
#                '2015-03-09', '2015-03-10', '2015-03-11', '2015-03-12',
#                '2015-03-13', '2015-03-16',
#                ...
#                '2019-04-17', '2019-04-18', '2019-04-22', '2019-04-23',
#                '2019-04-24', '2019-04-25', '2019-04-26', '2019-04-29',
#                '2019-04-30', '2019-05-01'],
#               dtype='datetime64[ns]', name='Date', length=1059, freq=None)

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic return
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(algo_returns_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_returns.sort_index(ascending = True, inplace = True)
algo_returns.head(100)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2014-10-10 -0.012612 -0.011752
# 2014-10-13 -0.018528 -0.002009
# 2014-10-14  0.000702  0.004501
# 2014-10-15  0.021616 -0.000977
# 2014-10-16  0.098246  0.083734
#
# [100 rows x 2 columns]

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns.dropna(inplace = True)
algo_returns.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
algo_returns.dtypes
# Out:
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
algo_returns.index
# Out:
# DatetimeIndex(['2014-06-05', '2014-06-06', '2014-06-09', '2014-06-10',
#                '2014-06-11', '2014-06-12', '2014-06-13', '2014-06-16',
#                '2014-06-17', '2014-06-18',
#                ...
#                '2019-04-17', '2019-04-18', '2019-04-22', '2019-04-23',
#                '2019-04-24', '2019-04-25', '2019-04-26', '2019-04-29',
#                '2019-04-30', '2019-05-01'],
#               dtype='datetime64[ns]', name='Date', length=1235, freq=None)

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Price
sp_tsx_history_path = Path("Resources/sp_tsx_history.csv")
sp_tsx_history = pd.read_csv(sp_tsx_history_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp_tsx_history.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sp_tsx_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp_tsx_history.sort_index(ascending = True, inplace = True)

# %%
# Fix Data Types
sp_tsx_history["Close"] = sp_tsx_history["Close"].str.replace("$", "")
sp_tsx_history["Close"] = sp_tsx_history["Close"].str.replace(",", "")
sp_tsx_history["Close"] = sp_tsx_history["Close"].astype("float")
sp_tsx_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
#sp_tsx_history["Close"] = sp_tsx_history["Close"].astype('float')
sp_tsx_history.head()
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
# Calculate Daily Returns
sp_daily_returns = sp_tsx_history.pct_change()
sp_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Drop nulls
sp_daily_returns.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %%
sp_daily_returns = sp_daily_returns.dropna()

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_daily_returns.columns = ['SP Daily Returns']
sp_daily_returns.head(200)
# Out:
#             SP Daily Returns
# Date
# 2012-10-02          0.001701
# 2012-10-03         -0.002563
# 2012-10-04          0.007137
# 2012-10-05         -0.002305
# 2012-10-09         -0.011709
# ...                      ...
# 2013-07-12         -0.002488
# 2013-07-15          0.005310
# 2013-07-16         -0.000915
# 2013-07-17          0.004145
# 2013-07-18          0.004780
#
# [200 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_returns, algo_returns, sp_daily_returns], axis="columns", join="inner")

combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP Daily Returns
# Date
# 2015-03-03 -0.000949         -0.008530
# 2015-03-04  0.002416         -0.003371
# ...

# %%
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
algo_returns.tail()
# Out:
#               Algo 1    Algo 2
# Date
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize = (20,10))

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_df_cumulative = (1+ combined_df).cumprod()

# Plot cumulative returns
combined_df_cumulative.plot(figsize = (20,10))

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P TSX 60
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.plot(kind = "box", figsize = (20,10))

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
standard_deviation_df = combined_df.std()
standard_deviation_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# SP Daily Returns               0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
sp60_standard_deviation = standard_deviation_df.loc["SP Daily Returns"]
print("S&P 60:", sp60_standard_deviation)
# Determine which portfolios are riskier than the S&P TSX 60
standard_deviation_df.sort_values(inplace=True)
standard_deviation_df
# Out:
# S&P 60: 0.007034167748577725
# PAULSON & CO.INC.              0.006982
# SP Daily Returns               0.007034
# Algo 1                         0.007589
# SOROS FUND MANAGEMENT LLC      0.007828
# Algo 2                         0.008326
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = combined_df.std() * np.sqrt(252)
annualized_std.sort_values(inplace=True)
annualized_std
# Out:
# PAULSON & CO.INC.              0.110841
# SP Daily Returns               0.111664
# Algo 1                         0.120470
# SOROS FUND MANAGEMENT LLC      0.124259
# Algo 2                         0.132177
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P TSX 60 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60
# 3. Calculate and plot a 60-day Beta for Berkshire Hathaway Inc compared to the S&P 60 TSX

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_df.rolling(window=21).std().plot(figsize = (20,10))
# Plot the rolling standard deviation

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_df.corr()
# Display de correlation matrix
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# SP Daily Returns                              0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# ...

# %%
print("Algo 2 best mimicks the S&P")
# Out:
# Algo 2 best mimicks the S&P

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
covariance = combined_df["BERKSHIRE HATHAWAY INC"].cov(combined_df["SP Daily Returns"])
covariance
# Out:
# 5.027336077110027e-05

# %%
# Calculate variance of S&P TSX
sp_variance = combined_df['SP Daily Returns'].var()
sp_variance
# Out:
# 4.9479515915131015e-05

# %%
# Computing beta
Berkshire_Beta = covariance / sp_variance
Berkshire_Beta
# Out:
# 1.016043909106364

# %%
# Plot beta trend, 30 rolling covariance
rolling_covariance = combined_df['BERKSHIRE HATHAWAY INC'].rolling(window=30).cov(combined_df['SP Daily Returns'])
rolling_covariance.plot(figsize=(20, 10), title='Rolling 30-Day Covariance')

# %%
# 30 rolling variance
rolling_variance = combined_df['SP Daily Returns'].rolling(window=30).var()
rolling_variance.plot(figsize=(20, 10), title='Rolling 30-Day Variance of S&P Returns')

# %%
# 30 day rolling Beta 
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 30-Day Beta')

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
combined_df_ewm = combined_df.ewm(span = 21,adjust = False).mean()
(1+combined_df_ewm).cumprod().plot(figsize = (20,10))

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = combined_df.mean()*252/(combined_df.std()*np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# SP Daily Returns               0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind = "bar", title = "Sharpe Ratios")

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Algo 1 does outperform S&P TSX 60 and the Whales!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
# Reading data from 1st stock
shop_returns_path = Path("Resources/shop_historical.csv")
shop_returns = pd.read_csv(shop_returns_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
shop_returns.head()
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
shop_returns.rename(columns = {"Close":"SHOP"}, inplace = True)
shop_returns.head()
# Out:
#            Symbol    SHOP
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
shop_returns = shop_returns.drop('Symbol', 1)
shop_returns.head()
# Out:
#               SHOP
# Date
# 2018-01-02  132.06
# 2018-01-03  135.15
# 2018-01-04  137.46
# 2018-01-05  137.26
# 2018-01-08  139.51

# %%
# Reading data from 2nd stock
otex_returns_path = Path("Resources/otex_historical.csv")
otex_returns = pd.read_csv(otex_returns_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
otex_returns.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
otex_returns.rename(columns = {"Close":"OTEX"}, inplace = True)
otex_returns.head()
# Out:
#            Symbol   OTEX
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
otex_returns = otex_returns.drop('Symbol', 1)
otex_returns.head()
# Out:
#              OTEX
# Date
# 2018-01-02  43.58
# 2018-01-03  43.07
# 2018-01-04  42.91
# 2018-01-05  42.57
# 2018-01-08  42.16

# %%
# Reading data from 3rd stock
loblaws_returns_path = Path("Resources/l_historical.csv")
loblaws_returns = pd.read_csv(loblaws_returns_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
loblaws_returns.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
loblaws_returns.rename(columns = {"Close":"L"}, inplace = True)
loblaws_returns.head()
# Out:
#            Symbol      L
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
loblaws_returns = loblaws_returns.drop('Symbol', 1)
loblaws_returns.head()
# Out:
#                 L
# Date
# 2018-01-02  57.99
# 2018-01-03  57.41
# 2018-01-04  57.42
# 2018-01-05  57.42
# 2018-01-08  56.86

# %%
# Combine all stocks in a single DataFrame
combined_portfolio_df = pd.concat([shop_returns, otex_returns, loblaws_returns], axis="columns", join="inner")

combined_portfolio_df.head()
# Out:
#               SHOP   OTEX      L
# Date
# 2018-01-02  132.06  43.58  57.99
# 2018-01-03  135.15  43.07  57.41
# 2018-01-04  137.46  42.91  57.42
# 2018-01-05  137.26  42.57  57.42
# 2018-01-08  139.51  42.16  56.86

# %%
# Reset Date index
#combined_df.reset_index()

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns
combined_daily_returns = combined_portfolio_df.pct_change()
# Drop NAs
combined_daily_returns.dropna(inplace=True)
# Display sample data
combined_daily_returns.head()
# Out:
#                 SHOP      OTEX         L
# Date
# 2018-01-03  0.023398 -0.011703 -0.010002
# 2018-01-04  0.017092 -0.003715  0.000174
# 2018-01-05 -0.001455 -0.007924  0.000000
# 2018-01-08  0.016392 -0.009631 -0.009753
# 2018-01-09 -0.011254 -0.000712  0.008969

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
combined_weighted_returns = combined_daily_returns.dot(weights)
# Display sample data
combined_weighted_returns.head()
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_portfolio_returns = pd.concat((combined_weighted_returns,combined_df), axis="columns", join="inner")
combined_portfolio_returns.rename(columns = {0:"my_portfolio"}, inplace=True)
combined_portfolio_returns
# Out:
#             my_portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03      0.000565                   0.004658            0.000027
# 2018-01-04      0.004517                  -0.000914            0.004196
# 2018-01-05     -0.003126                   0.004072            0.000823
# 2018-01-08     -0.000997                   0.004473           -0.003739
# 2018-01-09     -0.000999                  -0.001028            0.000872
# ...                  ...                        ...                 ...
# 2019-04-25      0.003461                  -0.000285           -0.001291
# 2019-04-26      0.003243                   0.008149            0.009162
# 2019-04-29      0.003303                   0.001254            0.002719
# 2019-04-30      0.026937                  -0.001295           -0.002211
# 2019-05-01     -0.000079                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_portfolio_returns.dropna(inplace=True)
combined_portfolio_returns
# Out:
#             my_portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03      0.000565                   0.004658            0.000027
# 2018-01-04      0.004517                  -0.000914            0.004196
# 2018-01-05     -0.003126                   0.004072            0.000823
# 2018-01-08     -0.000997                   0.004473           -0.003739
# 2018-01-09     -0.000999                  -0.001028            0.000872
# ...                  ...                        ...                 ...
# 2019-04-25      0.003461                  -0.000285           -0.001291
# 2019-04-26      0.003243                   0.008149            0.009162
# 2019-04-29      0.003303                   0.001254            0.002719
# 2019-04-30      0.026937                  -0.001295           -0.002211
# 2019-05-01     -0.000079                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
combined_annualized_std = combined_portfolio_returns.std() * np.sqrt(252)
combined_annualized_std.sort_values(inplace=True)
combined_annualized_std
# Out:
# SP Daily Returns               0.099121
# PAULSON & CO.INC.              0.114343
# Algo 1                         0.120028
# Algo 2                         0.137664
# SOROS FUND MANAGEMENT LLC      0.145675
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# my_portfolio                   0.224346
# BERKSHIRE HATHAWAY INC         0.227445
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_portfolio_returns.rolling(window=21).std().plot(figsize = (20,10))
# Plot rolling standard deviation

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_of_combined = combined_portfolio_returns.corr()
correlation_of_combined
# Out:
#                              my_portfolio  SOROS FUND MANAGEMENT LLC  \
# my_portfolio                     1.000000                   0.556093
# SOROS FUND MANAGEMENT LLC        0.556093                   1.000000
# PAULSON & CO.INC.                0.385305                   0.764174
# TIGER GLOBAL MANAGEMENT LLC      0.303971                   0.526710
# BERKSHIRE HATHAWAY INC           0.647413                   0.782414
# Algo 1                           0.214770                   0.305525
# Algo 2                           0.563756                   0.834431
# SP Daily Returns                 0.579228                   0.686681
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# my_portfolio                           0.385305                     0.303971
# SOROS FUND MANAGEMENT LLC              0.764174                     0.526710
# PAULSON & CO.INC.                      1.000000                     0.536534
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(correlation_of_combined, vmin=-1, vmax=1)

# %% [markdown]
# ### Calculate and Plot Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
# covariance of my portfolio
covariance_combined = combined_portfolio_returns["my_portfolio"].cov(combined_portfolio_returns["SP Daily Returns"])
covariance_combined
# Out:
# 5.111305460230443e-05

# %%
# S&P variance
sp_variance_combined = combined_portfolio_returns['SP Daily Returns'].var()
sp_variance_combined
# Out:
# 3.898788619333669e-05

# %%
# Beta
my_portfolio_Beta = covariance_combined / sp_variance_combined
my_portfolio_Beta
# Out:
# 1.3109983534075265

# %%
# 30 day rolling covariance
rolling_covariance_com = combined_portfolio_returns['my_portfolio'].rolling(window=30).cov(combined_portfolio_returns['SP Daily Returns'])
rolling_covariance_com.plot(figsize=(20, 10), title='Rolling 30-Day Covariance')

# %%
# 30 day rooling variance
rolling_variance_com = combined_portfolio_returns['SP Daily Returns'].rolling(window=30).var()
rolling_variance_com.plot(figsize=(20, 10), title='Rolling 30-Day Variance of S&P Returns')

# %%
rolling_beta_com = rolling_covariance_com / rolling_variance_com
rolling_beta_com.plot(figsize=(20, 10), title='Rolling 30-Day Beta')

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe_ratios_com = combined_portfolio_returns.mean()*252/(combined_portfolio_returns.std()*np.sqrt(252))
sharpe_ratios_com
# Out:
# my_portfolio                   1.564547
# SOROS FUND MANAGEMENT LLC     -0.088196
# PAULSON & CO.INC.             -0.396282
# TIGER GLOBAL MANAGEMENT LLC   -1.391612
# BERKSHIRE HATHAWAY INC         0.195907
# Algo 1                         1.901461
# Algo 2                         0.021394
# SP Daily Returns               0.034651
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_com.plot(kind = "bar", title = "Sharpe Ratios")

# %% [markdown]
# ### How does your portfolio do?
#
# My portfolio is second best.
